# %%
print(1+2)
# Out:
# 3

# %%
print(45 + 18)
print(30 - 12)
print(15 * 6)
print(30 / 3)
print(45 % 8)
# Out:
# 63
# 18
# 90
# 10.0
# 5

# %%
print(4+ .8)
print(3 -1.2)
print(15 * 0.6)
print(3 / 0.3)
print(45 % 0.8)
# Out:
# 46.8
# 1.8
# 9.0
# 10.0
# 0.1999999999999975

# %%
print("今日の天気は" + "晴れ")
print("今日の天気は""晴れ")
# Out:
# 今日の天気は晴れ
# 今日の天気は晴れ

# %%
print("降水確率" + str(50) + "%")
# Out:
# 降水確率50%

# %%
print("晴れ" *5)
print("晴れ" + "晴れ" + "晴れ" + "晴れ" + "晴れ")
# Out:
# 晴れ晴れ晴れ晴れ晴れ
# 晴れ晴れ晴れ晴れ晴れ

# %%
user_name = "侍太郎"
print(user_name)

user_name = "杉山友利子"
print(user_name)
# Out:
# 侍太郎
# 杉山友利子

# %%
#  整数型と浮動小数点型の足し算
number1 = 5
number2 =2.5
print(number1 + number2)

# 文字列型と文字列型の連結
last_name = "侍"
first_name = "太郎"
print(last_name + first_name)
# Out:
# 7.5
# 侍太郎

# %%
last_name = "侍"
first_name = "太郎"
sister_name = "花子"
print(f"私の名前は{last_name}{first_name}です。妹の名前は{sister_name}です。")
# Out:
# 私の名前は侍太郎です。妹の名前は花子です。

# %%
top =  10
bottom = 20
high = 5
print(f"{((top + bottom)*high)/2}㎤")
# Out:
# 75.0㎤
