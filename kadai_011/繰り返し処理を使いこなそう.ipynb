# %%
arrays = ["水","金","地","火","木","土","天","海","冥"]
for i in range(2):
 for array in arrays:
  print(array)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
arrays = ["水","金","地","火","木","土","天","海","冥"]
a = 0

while a < 18:
  print(arrays[a % 9])
  a += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
